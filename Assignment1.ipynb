# %% [markdown]
# Installed the following libraries
# pandas
# numpy
# matplotlib
# scipy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load Data

# %%
ap = pd.read_csv('datasets/application_train.csv')
b = pd.read_csv('datasets/bureau.csv')
ccb = pd.read_csv('datasets/credit_card_balance.csv')
pp = pd.read_csv('datasets/previous_application.csv')

# %% [markdown]
# Glance at Data

# %%
ap.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
b.describe()
# Out:
#          SK_ID_CURR  SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# count  1.716428e+06  1.716428e+06  1.716428e+06        1.716428e+06
# mean   2.782149e+05  5.924434e+06 -1.142108e+03        8.181666e-01
# std    1.029386e+05  5.322657e+05  7.951649e+02        3.654443e+01
# min    1.000010e+05  5.000000e+06 -2.922000e+03        0.000000e+00
# 25%    1.888668e+05  5.463954e+06 -1.666000e+03        0.000000e+00
# 50%    2.780550e+05  5.926304e+06 -9.870000e+02        0.000000e+00
# 75%    3.674260e+05  6.385681e+06 -4.740000e+02        0.000000e+00
# max    4.562550e+05  6.843457e+06  0.000000e+00        2.792000e+03
#
#        DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# count         1.610875e+06       1.082775e+06            5.919400e+05
# mean          5.105174e+02      -1.017437e+03            3.825418e+03
# std           4.994220e+03       7.140106e+02            2.060316e+05
# min          -4.206000e+04      -4.202300e+04            0.000000e+00
# ...

# %%
ccb.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  MONTHS_BALANCE   AMT_BALANCE  \
# count  3.840312e+06  3.840312e+06    3.840312e+06  3.840312e+06
# mean   1.904504e+06  2.783242e+05   -3.452192e+01  5.830016e+04
# std    5.364695e+05  1.027045e+05    2.666775e+01  1.063070e+05
# min    1.000018e+06  1.000060e+05   -9.600000e+01 -4.202502e+05
# 25%    1.434385e+06  1.895170e+05   -5.500000e+01  0.000000e+00
# 50%    1.897122e+06  2.783960e+05   -2.800000e+01  0.000000e+00
# 75%    2.369328e+06  3.675800e+05   -1.100000e+01  8.904669e+04
# max    2.843496e+06  4.562500e+05   -1.000000e+00  1.505902e+06
#
#        AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# count             3.840312e+06              3.090496e+06
# mean              1.538080e+05              5.961325e+03
# std               1.651457e+05              2.822569e+04
# min               0.000000e+00             -6.827310e+03
# 25%               4.500000e+04              0.000000e+00
# ...

# %%
pp.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR   AMT_ANNUITY  AMT_APPLICATION  \
# count  1.670214e+06  1.670214e+06  1.297979e+06     1.670214e+06
# mean   1.923089e+06  2.783572e+05  1.595512e+04     1.752339e+05
# std    5.325980e+05  1.028148e+05  1.478214e+04     2.927798e+05
# min    1.000001e+06  1.000010e+05  0.000000e+00     0.000000e+00
# 25%    1.461857e+06  1.893290e+05  6.321780e+03     1.872000e+04
# 50%    1.923110e+06  2.787145e+05  1.125000e+04     7.104600e+04
# 75%    2.384280e+06  3.675140e+05  2.065842e+04     1.803600e+05
# max    2.845382e+06  4.562550e+05  4.180581e+05     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  1.670213e+06      7.743700e+05     1.284699e+06
# mean   1.961140e+05      6.697402e+03     2.278473e+05
# std    3.185746e+05      2.092150e+04     3.153966e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    2.416050e+04      0.000000e+00     5.084100e+04
# ...

# %% [markdown]
# Numerical analysis and Visualization

# %%
ap['AMT_INCOME_TOTAL'].describe()
# Out:
# count    3.075110e+05
# mean     1.687979e+05
# std      2.371231e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.471500e+05
# 75%      2.025000e+05
# max      1.170000e+08
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
ap['AMT_INCOME_TOTAL'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot:>

# %%
ap['AMT_INCOME_TOTAL'].plot(kind='density', figsize=(14,6))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
ax = ap['AMT_INCOME_TOTAL'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Records')
ax.set_xlabel('dolars')
# Out:
# Text(0.5, 0, 'dolars')

# %% [markdown]
# Categorical Analysis and Visualization

# %%
ap['FLAG_OWN_REALTY'].value_counts()
#ap['CNT_FAM_MEMBERS'].value_counts()
# Out:
# 2.0     158357
# 1.0      67847
# 3.0      52601
# 4.0      24697
# 5.0       3478
# 6.0        408
# 7.0         81
# 8.0         20
# 9.0          6
# 10.0         3
# 14.0         2
# 12.0         2
# 20.0         2
# 16.0         2
# 13.0         1
# 15.0         1
# 11.0         1
# Name: CNT_FAM_MEMBERS, dtype: int64

# %%
ax = ap['FLAG_OWN_REALTY'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('count')

# %% [markdown]
# Relationship Of Data

# %%
corr = ap.corr()
corr
# Out:
#                             SK_ID_CURR    TARGET  CNT_CHILDREN  \
# SK_ID_CURR                    1.000000 -0.002108     -0.001129
# TARGET                       -0.002108  1.000000      0.019187
# CNT_CHILDREN                 -0.001129  0.019187      1.000000
# AMT_INCOME_TOTAL             -0.001820 -0.003982      0.012882
# AMT_CREDIT                   -0.000343 -0.030369      0.002145
# ...                                ...       ...           ...
# AMT_REQ_CREDIT_BUREAU_DAY    -0.002193  0.002704     -0.000366
# AMT_REQ_CREDIT_BUREAU_WEEK    0.002099  0.000788     -0.002436
# AMT_REQ_CREDIT_BUREAU_MON     0.000485 -0.012462     -0.010808
# AMT_REQ_CREDIT_BUREAU_QRT     0.001025 -0.002022     -0.007836
# AMT_REQ_CREDIT_BUREAU_YEAR    0.004659  0.019930     -0.041550
#
#                             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# SK_ID_CURR                         -0.001820   -0.000343    -0.000433
# ...

# %%
fig = plt.figure(figsize=(25,25), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7ce949acd9d0>,
# ...
#  [Text(0, 0, 'SK_ID_CURR'),
#   Text(0, 1, 'TARGET'),
#   Text(0, 2, 'CNT_CHILDREN'),
#   Text(0, 3, 'AMT_INCOME_TOTAL'),
#   Text(0, 4, 'AMT_CREDIT'),
#   Text(0, 5, 'AMT_ANNUITY'),
#   Text(0, 6, 'AMT_GOODS_PRICE'),
#   Text(0, 7, 'REGION_POPULATION_RELATIVE'),
#   Text(0, 8, 'DAYS_BIRTH'),
#   Text(0, 9, 'DAYS_EMPLOYED'),
#   Text(0, 10, 'DAYS_REGISTRATION'),
#   Text(0, 11, 'DAYS_ID_PUBLISH'),
#   Text(0, 12, 'OWN_CAR_AGE'),
#   Text(0, 13, 'FLAG_MOBIL'),
#   Text(0, 14, 'FLAG_EMP_PHONE'),
#   Text(0, 15, 'FLAG_WORK_PHONE'),
#   Text(0, 16, 'FLAG_CONT_MOBILE'),
#   Text(0, 17, 'FLAG_PHONE'),
#   Text(0, 18, 'FLAG_EMAIL'),
#   Text(0, 19, 'CNT_FAM_MEMBERS'),
#   Text(0, 20, 'REGION_RATING_CLIENT'),
#   Text(0, 21, 'REGION_RATING_CLIENT_W_CITY'),
#   Text(0, 22, 'HOUR_APPR_PROCESS_START'),
#   Text(0, 23, 'REG_REGION_NOT_LIVE_REGION'),
#   Text(0, 24, 'REG_REGION_NOT_WORK_REGION'),
#   Text(0, 25, 'LIVE_REGION_NOT_WORK_REGION'),
# ...

# %%
#ap.plot.scatter(x='TARGET', y='AMT_INCOME_TOTAL') #y='CNT_FAM_MEMBERS') #(kind='scatter', y='CNT_FAM_MEMBERS', x='TARGET', figsize=(6.6))
# Out:
# <AxesSubplot:xlabel='TARGET', ylabel='AMT_INCOME_TOTAL'>

# %%
corr = b.corr()
corr
# Out:
#                         SK_ID_CURR  SK_ID_BUREAU  DAYS_CREDIT  \
# SK_ID_CURR                1.000000      0.000135     0.000266
# SK_ID_BUREAU              0.000135      1.000000     0.013015
# DAYS_CREDIT               0.000266      0.013015     1.000000
# CREDIT_DAY_OVERDUE        0.000283     -0.002628    -0.027266
# DAYS_CREDIT_ENDDATE       0.000456      0.009107     0.225682
# DAYS_ENDDATE_FACT        -0.000648      0.017890     0.875359
# AMT_CREDIT_MAX_OVERDUE    0.001329      0.002290    -0.014724
# CNT_CREDIT_PROLONG       -0.000388     -0.000740    -0.030460
# AMT_CREDIT_SUM            0.001179      0.007962     0.050883
# AMT_CREDIT_SUM_DEBT      -0.000790      0.005732     0.135397
# AMT_CREDIT_SUM_LIMIT     -0.000304     -0.003986     0.025140
# AMT_CREDIT_SUM_OVERDUE   -0.000014     -0.000499    -0.000383
# DAYS_CREDIT_UPDATE        0.000510      0.019398     0.688771
# AMT_ANNUITY              -0.002727      0.001799     0.005676
#
# ...

# %%
fig = plt.figure(figsize=(25,25), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7f05f97b3190>,
# ...
#  [Text(0, 0, 'SK_ID_CURR'),
#   Text(0, 1, 'SK_ID_BUREAU'),
#   Text(0, 2, 'DAYS_CREDIT'),
#   Text(0, 3, 'CREDIT_DAY_OVERDUE'),
#   Text(0, 4, 'DAYS_CREDIT_ENDDATE'),
#   Text(0, 5, 'DAYS_ENDDATE_FACT'),
#   Text(0, 6, 'AMT_CREDIT_MAX_OVERDUE'),
#   Text(0, 7, 'CNT_CREDIT_PROLONG'),
#   Text(0, 8, 'AMT_CREDIT_SUM'),
#   Text(0, 9, 'AMT_CREDIT_SUM_DEBT'),
#   Text(0, 10, 'AMT_CREDIT_SUM_LIMIT'),
#   Text(0, 11, 'AMT_CREDIT_SUM_OVERDUE'),
#   Text(0, 12, 'DAYS_CREDIT_UPDATE'),
#   Text(0, 13, 'AMT_ANNUITY')])

# %%
corr = ccb.corr()
corr
# Out:
#                             SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  \
# SK_ID_PREV                    1.000000    0.004723        0.003670
# SK_ID_CURR                    0.004723    1.000000        0.001696
# MONTHS_BALANCE                0.003670    0.001696        1.000000
# AMT_BALANCE                   0.005046    0.003510        0.014558
# AMT_CREDIT_LIMIT_ACTUAL       0.006631    0.005991        0.199900
# AMT_DRAWINGS_ATM_CURRENT      0.004342    0.000814        0.036802
# AMT_DRAWINGS_CURRENT          0.002624    0.000708        0.065527
# AMT_DRAWINGS_OTHER_CURRENT   -0.000160    0.000958        0.000405
# AMT_DRAWINGS_POS_CURRENT      0.001721   -0.000786        0.118146
# AMT_INST_MIN_REGULARITY       0.006460    0.003300       -0.087529
# AMT_PAYMENT_CURRENT           0.003472    0.000127        0.076355
# AMT_PAYMENT_TOTAL_CURRENT     0.001641    0.000784        0.035614
# AMT_RECEIVABLE_PRINCIPAL      0.005140    0.003589        0.016266
# ...

# %%
fig = plt.figure(figsize=(25,25), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7f05f972de20>,
# ...
#  [Text(0, 0, 'SK_ID_PREV'),
#   Text(0, 1, 'SK_ID_CURR'),
#   Text(0, 2, 'MONTHS_BALANCE'),
#   Text(0, 3, 'AMT_BALANCE'),
#   Text(0, 4, 'AMT_CREDIT_LIMIT_ACTUAL'),
#   Text(0, 5, 'AMT_DRAWINGS_ATM_CURRENT'),
#   Text(0, 6, 'AMT_DRAWINGS_CURRENT'),
#   Text(0, 7, 'AMT_DRAWINGS_OTHER_CURRENT'),
#   Text(0, 8, 'AMT_DRAWINGS_POS_CURRENT'),
#   Text(0, 9, 'AMT_INST_MIN_REGULARITY'),
#   Text(0, 10, 'AMT_PAYMENT_CURRENT'),
#   Text(0, 11, 'AMT_PAYMENT_TOTAL_CURRENT'),
#   Text(0, 12, 'AMT_RECEIVABLE_PRINCIPAL'),
#   Text(0, 13, 'AMT_RECIVABLE'),
#   Text(0, 14, 'AMT_TOTAL_RECEIVABLE'),
#   Text(0, 15, 'CNT_DRAWINGS_ATM_CURRENT'),
#   Text(0, 16, 'CNT_DRAWINGS_CURRENT'),
#   Text(0, 17, 'CNT_DRAWINGS_OTHER_CURRENT'),
#   Text(0, 18, 'CNT_DRAWINGS_POS_CURRENT'),
#   Text(0, 19, 'CNT_INSTALMENT_MATURE_CUM'),
#   Text(0, 20, 'SK_DPD'),
#   Text(0, 21, 'SK_DPD_DEF')])

# %%
corr = pp.corr()
corr
# Out:
#                            SK_ID_PREV  SK_ID_CURR  AMT_ANNUITY  \
# SK_ID_PREV                   1.000000   -0.000321     0.011459
# SK_ID_CURR                  -0.000321    1.000000     0.000577
# AMT_ANNUITY                  0.011459    0.000577     1.000000
# AMT_APPLICATION              0.003302    0.000280     0.808872
# AMT_CREDIT                   0.003659    0.000195     0.816429
# AMT_DOWN_PAYMENT            -0.001313   -0.000063     0.267694
# AMT_GOODS_PRICE              0.015293    0.000369     0.820895
# HOUR_APPR_PROCESS_START     -0.002652    0.002842    -0.036201
# NFLAG_LAST_APPL_IN_DAY      -0.002828    0.000098     0.020639
# RATE_DOWN_PAYMENT           -0.004051    0.001158    -0.103878
# RATE_INTEREST_PRIMARY        0.012969    0.033197     0.141823
# RATE_INTEREST_PRIVILEGED    -0.022312   -0.016757    -0.202335
# DAYS_DECISION                0.019100   -0.000637     0.279051
# SELLERPLACE_AREA            -0.001079    0.001265    -0.015027
# ...

# %%
fig = plt.figure(figsize=(25,25), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7d453b48e2e0>,
# ...
#  [Text(0, 0, 'SK_ID_PREV'),
#   Text(0, 1, 'SK_ID_CURR'),
#   Text(0, 2, 'AMT_ANNUITY'),
#   Text(0, 3, 'AMT_APPLICATION'),
#   Text(0, 4, 'AMT_CREDIT'),
#   Text(0, 5, 'AMT_DOWN_PAYMENT'),
#   Text(0, 6, 'AMT_GOODS_PRICE'),
#   Text(0, 7, 'HOUR_APPR_PROCESS_START'),
#   Text(0, 8, 'NFLAG_LAST_APPL_IN_DAY'),
#   Text(0, 9, 'RATE_DOWN_PAYMENT'),
#   Text(0, 10, 'RATE_INTEREST_PRIMARY'),
#   Text(0, 11, 'RATE_INTEREST_PRIVILEGED'),
#   Text(0, 12, 'DAYS_DECISION'),
#   Text(0, 13, 'SELLERPLACE_AREA'),
#   Text(0, 14, 'CNT_PAYMENT'),
#   Text(0, 15, 'DAYS_FIRST_DRAWING'),
#   Text(0, 16, 'DAYS_FIRST_DUE'),
#   Text(0, 17, 'DAYS_LAST_DUE_1ST_VERSION'),
#   Text(0, 18, 'DAYS_LAST_DUE'),
#   Text(0, 19, 'DAYS_TERMINATION'),
#   Text(0, 20, 'NFLAG_INSURED_ON_APPROVAL')])

# %% [markdown]
# Joinned Dataset Analysis

# %%
arr = {
    'target': ap['TARGET'],
    'key_id': ap['SK_ID_CURR'],
    'amount_income_total': ap['AMT_INCOME_TOTAL'],
    'amount_credit': ap['AMT_CREDIT'],
    'amount_goods_price': ap['AMT_GOODS_PRICE'],
    'amount_annuity':  ap['AMT_ANNUITY'],
    'amount_credit_sum': b['AMT_CREDIT_SUM'],
#    'acmo': b['AMT_CREDIT_MAX_OVERDUE'],
    'amount_credit_sum_debt': b['AMT_CREDIT_SUM_DEBT'],
#    'aa': b['AMT_ANNUITY'],
    'amout_balance': ccb['AMT_BALANCE'],
    'amout_receivable': ccb['AMT_RECIVABLE'],
    'amout_credit_limit_actual': ccb['AMT_CREDIT_LIMIT_ACTUAL'],
    'amount_down_payment': pp['AMT_DOWN_PAYMENT'],
    'amount_application': pp['AMT_APPLICATION']
    }
df = pd.DataFrame(arr)
df.head()
# Out:
#    target    key_id  amount_income_total  amount_credit  amount_goods_price  \
# 0     1.0  100002.0             202500.0       406597.5            351000.0
# 1     0.0  100003.0             270000.0      1293502.5           1129500.0
# 2     0.0  100004.0              67500.0       135000.0            135000.0
# 3     0.0  100006.0             135000.0       312682.5            297000.0
# 4     0.0  100007.0             121500.0       513000.0            513000.0
#
#    amount_annuity  amount_credit_sum  amount_credit_sum_debt  amout_balance  \
# 0         24700.5            91323.0                     0.0         56.970
# 1         35698.5           225000.0                171342.0      63975.555
# 2          6750.0           464323.5                     NaN      31815.225
# 3         29686.5            90000.0                     NaN     236572.110
# 4         21865.5          2700000.0                     NaN     453919.455
#
# ...

# %%
df.describe()
# Out:
#               target         key_id  amount_income_total  amount_credit  \
# count  307511.000000  307511.000000         3.075110e+05   3.075110e+05
# mean        0.080729  278180.518577         1.687979e+05   5.990260e+05
# std         0.272419  102790.175348         2.371231e+05   4.024908e+05
# min         0.000000  100002.000000         2.565000e+04   4.500000e+04
# 25%         0.000000  189145.500000         1.125000e+05   2.700000e+05
# 50%         0.000000  278202.000000         1.471500e+05   5.135310e+05
# 75%         0.000000  367142.500000         2.025000e+05   8.086500e+05
# max         1.000000  456255.000000         1.170000e+08   4.050000e+06
#
#        amount_goods_price  amount_annuity  amount_credit_sum  \
# count        3.072330e+05   307499.000000       1.716415e+06
# mean         5.383962e+05    27108.573909       3.549946e+05
# std          3.694465e+05    14493.737315       1.149811e+06
# min          4.050000e+04     1615.500000       0.000000e+00
# ...

# %%
corr = df.corr()
corr
# Out:
#                              target    key_id  amount_income_total  \
# target                     1.000000 -0.002108            -0.003982
# key_id                    -0.002108  1.000000            -0.001820
# amount_income_total       -0.003982 -0.001820             1.000000
# amount_credit             -0.030369 -0.000343             0.156870
# amount_goods_price        -0.039645 -0.000232             0.159610
# amount_annuity            -0.012817 -0.000433             0.191657
# amount_credit_sum          0.000218 -0.006572            -0.000860
# amount_credit_sum_debt    -0.000946 -0.005050             0.000480
# amout_balance              0.000448  0.013622             0.004055
# amout_receivable           0.000412  0.013710             0.004059
# amout_credit_limit_actual  0.000515 -0.003466             0.001009
# amount_down_payment        0.002496  0.004439            -0.000897
# amount_application         0.001689  0.005663            -0.001428
#
# ...

# %%
fig = plt.figure(figsize=(16,16), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7d453933b820>,
# ...
#  [Text(0, 0, 'target'),
#   Text(0, 1, 'key_id'),
#   Text(0, 2, 'amount_income_total'),
#   Text(0, 3, 'amount_credit'),
#   Text(0, 4, 'amount_goods_price'),
#   Text(0, 5, 'amount_annuity'),
#   Text(0, 6, 'amount_credit_sum'),
#   Text(0, 7, 'amount_credit_sum_debt'),
#   Text(0, 8, 'amout_balance'),
#   Text(0, 9, 'amout_receivable'),
#   Text(0, 10, 'amout_credit_limit_actual'),
#   Text(0, 11, 'amount_down_payment'),
#   Text(0, 12, 'amount_application')])

# %% [markdown]
# The top ten variables for prediction are:
#
# 1. income amount total
# 1. credit amount
# 1. goods price amount
# 1. annuity amount
# 1. credit sum amount
# 1. credit sum debt amount
# 1. balance amount
# 1. receivable amount
# 1. credit limit actual amount
# 1. down payment amount
#
# The correlation values as seen below where used to determined the choices for the variables. Also, the use of the describe function from pandas was used to look at the mean, medium, and standard deviation.
#
# Other things considered when making the choice was for the income amount total because it should be necessary high to cover the annuity amount of the loan application and the balance amount on the credit card balance. Also, checking for the credit sum and credit sum debt amount could give an indication of the financial stability of the person. To mitigate the risk of the loan the goods price seems important for the decision and the receivalble amount last month to make sure the debt is getting paid. In addition, the down payment on the last loan is something good to check and the application amount from the last loan to see if the current request is more or less than what has been borrowed before.

# %%
df.describe()
# Out:
#               target         key_id  amount_income_total  amount_credit  \
# count  307511.000000  307511.000000         3.075110e+05   3.075110e+05
# mean        0.080729  278180.518577         1.687979e+05   5.990260e+05
# std         0.272419  102790.175348         2.371231e+05   4.024908e+05
# min         0.000000  100002.000000         2.565000e+04   4.500000e+04
# 25%         0.000000  189145.500000         1.125000e+05   2.700000e+05
# 50%         0.000000  278202.000000         1.471500e+05   5.135310e+05
# 75%         0.000000  367142.500000         2.025000e+05   8.086500e+05
# max         1.000000  456255.000000         1.170000e+08   4.050000e+06
#
#        amount_goods_price  amount_annuity  amount_credit_sum  \
# count        3.072330e+05   307499.000000       1.716415e+06
# mean         5.383962e+05    27108.573909       3.549946e+05
# std          3.694465e+05    14493.737315       1.149811e+06
# min          4.050000e+04     1615.500000       0.000000e+00
# ...

# %%
arr = {
    'target': ap['TARGET'],
    'key_id': ap['SK_ID_CURR'],
    'amount_income_total': ap['AMT_INCOME_TOTAL'],
    'amount_credit': ap['AMT_CREDIT'],
    'amount_goods_price': ap['AMT_GOODS_PRICE'],
    'amount_annuity':  ap['AMT_ANNUITY'],
    'amount_credit_sum': b['AMT_CREDIT_SUM'],
    'amount_credit_sum_debt': b['AMT_CREDIT_SUM_DEBT'],
    'amout_balance': ccb['AMT_BALANCE'],
    'amout_receivable': ccb['AMT_RECIVABLE'],
    'amount_application': pp['AMT_APPLICATION'],
    'amount_down_payment': pp['AMT_DOWN_PAYMENT'],
    'amount_application': pp['AMT_APPLICATION']
    }
df = pd.DataFrame(arr)
corr = df.corr()
corr
# Out:
#                           target    key_id  amount_income_total  \
# target                  1.000000 -0.002108            -0.003982
# key_id                 -0.002108  1.000000            -0.001820
# amount_income_total    -0.003982 -0.001820             1.000000
# amount_credit          -0.030369 -0.000343             0.156870
# amount_goods_price     -0.039645 -0.000232             0.159610
# amount_annuity         -0.012817 -0.000433             0.191657
# amount_credit_sum       0.000218 -0.006572            -0.000860
# amount_credit_sum_debt -0.000946 -0.005050             0.000480
# amout_balance           0.000448  0.013622             0.004055
# amout_receivable        0.000412  0.013710             0.004059
# amount_application      0.001689  0.005663            -0.001428
# amount_down_payment     0.002496  0.004439            -0.000897
#
#                         amount_credit  amount_goods_price  amount_annuity  \
# ...

# %%
fig = plt.figure(figsize=(16,16), facecolor='white')
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x7d45272dcf10>,
# ...
#  [Text(0, 0, 'target'),
#   Text(0, 1, 'key_id'),
#   Text(0, 2, 'amount_income_total'),
#   Text(0, 3, 'amount_credit'),
#   Text(0, 4, 'amount_goods_price'),
#   Text(0, 5, 'amount_annuity'),
#   Text(0, 6, 'amount_credit_sum'),
#   Text(0, 7, 'amount_credit_sum_debt'),
#   Text(0, 8, 'amout_balance'),
#   Text(0, 9, 'amout_receivable'),
#   Text(0, 10, 'amount_application'),
#   Text(0, 11, 'amount_down_payment')])
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ap['AMT_INCOME_TOTAL'].plot(kind='box', vert=False, figsize=(14,6))
